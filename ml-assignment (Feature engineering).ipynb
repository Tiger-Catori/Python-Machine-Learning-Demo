# %% [markdown]
# #### Importing libraries & loading the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.pandas.set_option('display.max_columns',None)
df = pd.read_csv('data/heart-disease.csv')
dataset = df.copy()
dataset.head()
# Out:
#     Age  Gender  Chest pain type  Resting blood pressure  Serum cholesterol  \
# 0  63.0     1.0              4.0                   140.0              260.0
# 1  44.0     1.0              4.0                   130.0              209.0
# 2  60.0     1.0              4.0                   132.0              218.0
# 3  55.0     1.0              4.0                   142.0              228.0
# 4  66.0     1.0              3.0                   110.0              213.0
#
#    Fasting blood sugar  Resting electrocardiographic  Maximum heart rate  \
# 0                  0.0                           1.0               112.0
# 1                  0.0                           1.0               127.0
# 2                  0.0                           1.0               140.0
# 3                  0.0                           1.0               149.0
# 4                  1.0                           2.0                99.0
#
#    Exercise induced angina  ST depression  ST segment  \
# 0                      1.0            3.0         2.0
# 1                      0.0            0.0         NaN
# 2                      1.0            1.5         3.0
# 3                      1.0            2.5         1.0
# 4                      1.0            1.3         2.0
#
#    Number of major vessels  Thal  class
# 0                      NaN   NaN      2
# 1                      NaN   NaN      0
# 2                      NaN   NaN      2
# 3                      NaN   NaN      1
# 4                      NaN   NaN      0

# %% [markdown]
# ##### We will be peforing the below steps in Feature engineering
# 1. Missing Values.
# 2. Standardise the values of the variables to the same range.

# %%
# Split sata into train and test
